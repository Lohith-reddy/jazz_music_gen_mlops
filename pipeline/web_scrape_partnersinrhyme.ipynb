# %%
import asyncio
import aiohttp
from bs4 import BeautifulSoup
import re

url = "https://www.partnersinrhyme.com/midi/Jazz/index.shtml"

async def download_midi(url, extracted_text):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            content = await response.read()
            file_path = "midi_data/" + extracted_text + ".mid"
            with open(file_path, "wb") as file:
                file.write(content)
                print("Downloaded", file_path)


async def main(url):  # Pass the url as an argument
    async with aiohttp.ClientSession() as session:
        response = await session.get(url)
        soup = BeautifulSoup(await response.text(), 'html.parser')

        collection_content = soup.find(class_="collection-content")
        href_list = [a['href'] for a in collection_content.find_all('a')]

        tasks = []
        for url in href_list:
            match = re.search(r"/(\w+)\.shtml", url)
            if match:
                extracted_text = match.group(1)
                download_link = "https://composerconnection.com/midi1/Jazz/" + extracted_text + ".mid"
                tasks.append(asyncio.create_task(download_midi(download_link, extracted_text=extracted_text)))

        downloaded_files = await asyncio.gather(*tasks)

await main(url)  # Pass the url as an argument
# Out:
# Downloaded data/autmnlev.mid
# Downloaded data/birlan2.mid
# Downloaded data/bigband.mid
# Downloaded data/atrain.mid
# Downloaded data/allblues.mid
# Downloaded data/4bros.mid
# Downloaded data/amazing.mid
# Downloaded data/ambiant.mid
# Downloaded data/cherokee.mid
# Downloaded data/alljarr.mid
# Downloaded data/crysslnc.mid
# Downloaded data/chipblue.mid
# Downloaded data/anotheru.mid
# Downloaded data/dreamy.mid
# Downloaded data/fuzion.mid
# Downloaded data/bethleem.mid
# Downloaded data/force.mid
# Downloaded data/011.mid
# Downloaded data/dolphns2.mid
# Downloaded data/count.mid
# Downloaded data/dgeneric.mid
# Downloaded data/flyaway.mid
# Downloaded data/bluset55.mid
# Downloaded data/ckick.mid
# Downloaded data/bluesy2.mid
# Downloaded data/django.mid
# Downloaded data/dreamy2.mid
# Downloaded data/cherok2.mid
# Downloaded data/dontget.mid
# Downloaded data/favthngs.mid
# Downloaded data/bounce.mid
# Downloaded data/again.mid
# Downloaded data/moaning.mid
# Downloaded data/jazz07.mid
# Downloaded data/hapbirth.mid
# Downloaded data/byt.mid
# Downloaded data/gmblues1.mid
# Downloaded data/georgiam.mid
# Downloaded data/gdvib6.mid
# Downloaded data/improv_1.mid
# Downloaded data/ipanema.mid
# Downloaded data/rnd_mid.mid
# Downloaded data/foregrou.mid
# Downloaded data/gtrblues.mid
# Downloaded data/jazz18.mid
# Downloaded data/dolphnst.mid
# Downloaded data/bop_on.mid
# Downloaded data/birdland.mid
# Downloaded data/nightuni.mid
# Downloaded data/knife.mid
# Downloaded data/dontmean.mid
# Downloaded data/ppanth.mid
# Downloaded data/improv_2.mid
# Downloaded data/improv_3.mid
# Downloaded data/onlylove.mid
# Downloaded data/gintonic.mid
# Downloaded data/newyork.mid
# Downloaded data/youdbe.mid
# Downloaded data/monk.mid
# Downloaded data/jazz10.mid
# Downloaded data/psr510_5.mid
# Downloaded data/ppanth2.mid
# Downloaded data/newhit.mid
# Downloaded data/mechano.mid
# Downloaded data/nuages.mid
# Downloaded data/metheny1.mid
# Downloaded data/israel.mid
# Downloaded data/new_york.mid
# Downloaded data/teentown.mid
# Downloaded data/fordebby.mid
# Downloaded data/happybdy.mid
# Downloaded data/Dfreesax.mid
# Downloaded data/fransroc.mid
# Downloaded data/slanted.mid
# Downloaded data/satindol.mid
# Downloaded data/jobim.mid
# Downloaded data/jazz11.mid
# Downloaded data/yyz.mid
# Downloaded data/stolen.mid
# Downloaded data/stthomas.mid
# Downloaded data/peace.mid
# Downloaded data/onestep.mid
# Downloaded data/someband.mid
# Downloaded data/samba1n.mid
# Downloaded data/take5.mid
# Downloaded data/lullaby.mid
# Downloaded data/tarkus.mid
# Downloaded data/train.mid
# Downloaded data/deadend.mid
# Downloaded data/zanzibar.mid
# Downloaded data/stella.mid
# Downloaded data/jazzy.mid
# Downloaded data/almonds.mid
# Downloaded data/worm.mid
# Downloaded data/pgunn.mid
# Downloaded data/techno78.mid
# Downloaded data/rndmdngt.mid
# Downloaded data/yebisu.mid
# Downloaded data/tribute.mid
# Downloaded data/suplex.mid
# Downloaded data/misty.mid
# Downloaded data/sthomas.mid
# Downloaded data/wefreeki.mid
# Downloaded data/ticotico.mid
# Downloaded data/wivelove.mid
# Downloaded data/opus1.mid
# Downloaded data/roadtrav.mid
# Downloaded data/minorsw.mid
# Downloaded data/jazz.mid
# Downloaded data/pop.mid
# Downloaded data/rainbow.mid
# Downloaded data/shiny.mid
# Downloaded data/lazybird.mid
# Downloaded data/softly.mid
# Downloaded data/spain.mid
