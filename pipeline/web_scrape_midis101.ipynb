# %%
import requests
import os
import requests
from bs4 import BeautifulSoup
import asyncio
import aiohttp

# %%
async def fetch_url(session, url):
    async with session.get(url) as response:
        return await response.text()

async def extract_hrefs(session, page):
    base_url = "https://www.midis101.com/search/jazz"
    if page == 1:
        url = f"{base_url}"
    else:
        url = f"{base_url}/pg-{page}"

    html_content = await fetch_url(session, url)
    soup = BeautifulSoup(html_content, "html.parser")

    td_elements = soup.find_all("td")
    hrefs = [td.find("a")["href"] for td in td_elements if td.find("a") and td.find("a")["href"] != 'javascript:;']

    return hrefs

async def download_hrefs(url, queue):
    url = "https://www.midis101.com" + url
    async with aiohttp.ClientSession() as session:
        html_content = await fetch_url(session, url)
        soup = BeautifulSoup(html_content, "html.parser")

        elements = soup.find_all(class_="btn btn-primary btn-lg btn-block p-4")
        hrefs = [element["href"] for element in elements]

        for href in hrefs:
            print(f"Extracted {href}")
            await queue.put(href)

async def download_midi(url, session):
    url = "https://www.midis101.com" + url
    # Extract the filename from the URL
    filename = url.split("/")[-1]

    # Check if the file already exists in the directory
    if os.path.exists(f"midi_data/{filename}"):
        print(f"Skipping {filename} (already exists)")
        return

    async with session.get(url) as response:
        # Save the MIDI file to the "midi_data" folder
        with open(f"midi_data/{filename}", "wb") as file:
            # Iterate over the response content asynchronously
            async for chunk in response.content.iter_any():
                file.write(chunk)

        print(f"Downloaded {filename}")

async def main():
    # Fetch and extract hrefs asynchronously for pages 1 to 21
    all_hrefs = []
    async with aiohttp.ClientSession() as session:
        tasks = [extract_hrefs(session, page) for page in range(1, 22)]
        all_hrefs_per_page = await asyncio.gather(*tasks)
        all_hrefs = [href for hrefs in all_hrefs_per_page for href in hrefs]

    # Create the "midi_data" folder if it doesn't exist
    if not os.path.exists("midi_data"):
        os.makedirs("midi_data")

    # Create a queue to store hrefs
    href_queue = asyncio.Queue()

    # Enqueue URLs directly into the href_queue
    tasks = [download_hrefs(url, href_queue) for url in all_hrefs]
    await asyncio.gather(*tasks)

    # Create a list to store download tasks
    download_tasks = []

    # Download MIDI files from the URLs in href_queue
    async with aiohttp.ClientSession() as session:
        while not href_queue.empty():
            href = await href_queue.get()
            url = "https://www.midis101.com" + href
            download_tasks.append(download_midi(url, session))

    # Concurrently download MIDI files
    await asyncio.gather(*download_tasks)

    print("MIDI files downloaded successfully.")

await main()

# %%
import os
folder_path = "midi_data"
file_count = len(os.listdir(folder_path))

print(f"Number of files in the '{folder_path}' folder: {file_count}")
# Out:
# Number of files in the 'data' folder: 603

# %% [markdown]
# ## EXperiments

# %%
async def fetch_url(session, url):
    async with session.get(url) as response:
        return await response.text()

async def extract_hrefs(session, page):
    base_url = "https://www.midis101.com/search/jazz"
    if page == 1:
        url = f"{base_url}"
    else:
        url = f"{base_url}/pg-{page}"

    html_content = await fetch_url(session, url)
    soup = BeautifulSoup(html_content, "html.parser")

    td_elements = soup.find_all("td")
    hrefs = [td.find("a")["href"] for td in td_elements if td.find("a") and td.find("a")["href"] != 'javascript:;']

    return hrefs

async def main_sub():
    all_hrefs = []

    # Create a new aiohttp session
    async with aiohttp.ClientSession() as session:
        # Fetch and extract hrefs asynchronously for pages 1 to 21
        tasks = [extract_hrefs(session, page) for page in range(1, 22)]
        all_hrefs_per_page = await asyncio.gather(*tasks)

        # Flatten the list of lists
        all_hrefs = [href for hrefs in all_hrefs_per_page for href in hrefs]

    return all_hrefs

# Run the event loop
all_hrefs = await main_sub()

# %%
async def download_hrefs(url, queue):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            # Parse the HTML content using BeautifulSoup
            soup = BeautifulSoup(await response.text(), "html.parser")

            # Find all elements with the class "btn btn-primary btn-lg btn-block p-4"
            elements = soup.find_all(class_="btn btn-primary btn-lg btn-block p-4")

            # Extract the hrefs from the elements
            hrefs = [element["href"] for element in elements]

            # Put the hrefs into the queue
            for href in hrefs:
                # print(f"Extracted {href}")
                await queue.put(href)

async def download_midi(url, session):
    # Extract the filename from the URL
    filename = url.split("/")[-1]

    # Check if the file already exists in the directory
    if os.path.exists(f"midi_midi_data/{filename}"):
        print(f"Skipping {filename} (already exists)")
        return

    async with session.get(url) as response:
        # Save the MIDI file to the "midi_data" folder
        with open(f"midi_data/{filename}", "wb") as file:
            # Iterate over the response content asynchronously
            async for chunk in response.content.iter_any():
                file.write(chunk)

        #print(f"Downloaded {filename}")


async def main():
    # Create the "midi_data" folder if it doesn't exist
    if not os.path.exists("midi_data"):
        os.makedirs("midi_data")

    # Create a queue to store hrefs
    href_queue = asyncio.Queue()

    # Create a list to store download tasks
    download_tasks = []

    # Iterate over the URLs in all_hrefs
    for url in all_hrefs:
        url = "https://www.midis101.com" + url

        # Send a GET request to the URL and extract hrefs
        download_tasks.append(download_hrefs(url, href_queue))

    # Concurrently extract hrefs
    await asyncio.gather(*download_tasks)

    # Create a list to store download tasks
    download_tasks = []

    # Download MIDI files from the URLs in href_queue
    async with aiohttp.ClientSession() as session:
        while not href_queue.empty():
            href = await href_queue.get()
            url = "https://www.midis101.com" + href
            download_tasks.append(download_midi(url, session))

    # Concurrently download MIDI files
        await asyncio.gather(*download_tasks)

    print("MIDI files downloaded successfully.")


await main()
# Out:
# Extracted /download/50600-jazz-unknown-jp059
# Extracted /download/50604-jazz-unknown-jp063
# Extracted /download/91999-drjazz
# Extracted /download/89630-jazztango
# Extracted /download/59488-tonny-bennet-young-and-foolish-jazz
# Extracted /download/50625-jazz-yebisu
# Extracted /download/89659-rockinjazz
# c:\Users\Lohit Reddy\anaconda3\envs\jazz_music_mlops\Lib\site-packages\bs4\__init__.py:616: RuntimeWarning: coroutine 'main' was never awaited
#   containerClass = self.string_container(containerClass)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#
# Extracted /download/50551-jazz-unknown-jp010
# Extracted /download/50533-jazz-unknown-angela
# Extracted /download/50563-jazz-unknown-jp022
# Extracted /download/50535-jazz-unknown-byt
# Extracted /download/50543-jazz-unknown-jp002
# Extracted /download/50606-jazz-unknown-jp065
# Extracted /download/50538-jazz-unknown-count-on-the-blues
# Extracted /download/50586-jazz-unknown-jp045
# Extracted /download/50549-jazz-unknown-jp008
# Extracted /download/50541-jazz-unknown-jazz-lagoon
# Extracted /download/50550-jazz-unknown-jp009
# Extracted /download/50557-jazz-unknown-jp016
# Extracted /download/50615-jazz-unknown-sockhop
# Extracted /download/50588-jazz-unknown-jp047
# Extracted /download/50505-jazz-rainbow
# Extracted /download/57740-sobol-acid-jazz
# Extracted /download/50537-jazz-unknown-cantalop
# Extracted /download/50573-jazz-unknown-jp032
# Extracted /download/50506-jazz-rnd-mid
# Extracted /download/50517-jazz-stand-by-me
# Extracted /download/50511-jazz-scheller-un-homme-heureux
# Extracted /download/50527-jazz-teentown
# Extracted /download/50493-jazz-nuages
# Extracted /download/50523-jazz-suplex
# Extracted /download/50510-jazz-satindol
# Extracted /download/50524-jazz-take5
# Extracted /download/50518-jazz-stella
# Extracted /download/50581-jazz-unknown-jp040
# Extracted /download/50528-jazz-the-shadow-of-your-smile
# Extracted /download/50529-jazz-ticotico
# Extracted /download/50572-jazz-unknown-jp031
# Extracted /download/50545-jazz-unknown-jp004
# Extracted /download/50594-jazz-unknown-jp053
# Extracted /download/50526-jazz-techno78
# Extracted /download/50497-jazz-opus1
# Extracted /download/50532-jazz-unknown-2nd-time-foreground
# Extracted /download/50516-jazz-spain
# Extracted /download/50531-jazz-tribute
# Extracted /download/50530-jazz-train
# Extracted /download/50504-jazz-psr510-5
# Extracted /download/50492-jazz-nougayork
# Extracted /download/50568-jazz-unknown-jp027
# Extracted /download/50454-jazz-gintonic
# Extracted /download/50566-jazz-unknown-jp025
# Extracted /download/50593-jazz-unknown-jp052
# Extracted /download/50502-jazz-ppanth2
# Extracted /download/50519-jazz-sthomas
# Extracted /download/50509-jazz-samba1n
# Extracted /download/50498-jazz-peace
# Extracted /download/50560-jazz-unknown-jp019
# Extracted /download/50522-jazz-summertime
# Extracted /download/50536-jazz-unknown-bop-on-the-rocks
# Extracted /download/50468-jazz-jazz10
# Extracted /download/50470-jazz-jazz18
# Extracted /download/50487-jazz-my-funny-valentin
# Extracted /download/50484-jazz-misty2
# Extracted /download/50482-jazz-minorsw
# Extracted /download/50434-jazz-dock-of-the-beat
# Extracted /download/50430-jazz-dixieland
# Extracted /download/50471-jazz-jazzy
# Extracted /download/50555-jazz-unknown-jp014
# Extracted /download/50444-jazz-flyaway
# Extracted /download/50480-jazz-meditation
# Extracted /download/50559-jazz-unknown-jp018
# Extracted /download/50415-jazz-chipblue
# Extracted /download/50491-jazz-nightuni
# Extracted /download/50435-jazz-dolphns2
# Extracted /download/50466-jazz-jazz
# Extracted /download/50473-jazz-jump-acc
# Extracted /download/50474-jazz-knife
# Extracted /download/50552-jazz-unknown-jp011
# Extracted /download/50432-jazz-dixielnd
# Extracted /download/50490-jazz-newyork
# Extracted /download/50553-jazz-unknown-jp012
# Extracted /download/50483-jazz-misty
# Extracted /download/50425-jazz-crysslnc
# Extracted /download/50447-jazz-foregrou
# Extracted /download/50481-jazz-metheny1
# Extracted /download/50467-jazz-jazz07
# Extracted /download/50451-jazz-georgiam
# Extracted /download/50442-jazz-fastjung
# Extracted /download/50410-jazz-bounce
# Extracted /download/50397-jazz-big-band
# Extracted /download/50514-jazz-softly
# Extracted /download/50393-jazz-basie
# Extracted /download/50401-jazz-bigband3
# Extracted /download/50488-jazz-new-york
# Extracted /download/50525-jazz-tarkus
# Extracted /download/50402-jazz-bigbandbalad
# Extracted /download/50462-jazz-improv-2
# Extracted /download/50433-jazz-django
# Extracted /download/50387-jazz-amazing
# Extracted /download/50449-jazz-fuzion
# Extracted /download/50414-jazz-cherokee
# Extracted /download/50419-jazz-cool-jazz1
# Extracted /download/50446-jazz-fordebby
# Extracted /download/50423-jazz-corea-2
# Extracted /download/50421-jazz-corcovado
# Extracted /download/50453-jazz-gershwin-rhapsody-in-blue
# Extracted /download/42617-claude-nougaro-le-jazz-et-la-java-2
# Extracted /download/50429-jazz-dgeneric
# Extracted /download/50443-jazz-favthngs
# Extracted /download/50507-jazz-rndmdngt
# Extracted /download/50417-jazz-colljazz
# Extracted /download/50512-jazz-shiny
# Extracted /download/34660-song-book-modjazz
# Extracted /download/50411-jazz-brubek-take-five
# Extracted /download/50428-jazz-dfreesax
# Extracted /download/50448-jazz-fransroc
# Extracted /download/50390-jazz-around-midnight
# Extracted /download/50416-jazz-ckick
# Extracted /download/50422-jazz-corea-1
# Extracted /download/50395-jazz-bebop
# Extracted /download/50452-jazz-gershwin-rhapsody-in-blue-piano
# Extracted /download/50392-jazz-autmnlev
# Extracted /download/50463-jazz-improv-3
# Extracted /download/50408-jazz-bluset55
# Extracted /download/50398-jazz-bigbald
# Extracted /download/50383-jazz-again
# Extracted /download/50489-jazz-newhit
# Extracted /download/50391-jazz-atrain
# Extracted /download/50396-jazz-bethleem
# Extracted /download/50413-jazz-cherok2
# Extracted /download/31725-midi-drums-drums-3of6-drums-swjazz
# Extracted /download/34485-sonar-jazz-240-swing-ride-half-time
# Extracted /download/50412-jazz-byt
# Extracted /download/34623-song-book-jazzfusi
# Extracted /download/31808-midi-drums-drums-4of6-drums-jazzsw-b
# Extracted /download/34625-song-book-jazzslow
# Extracted /download/50404-jazz-birdland
# Extracted /download/50440-jazz-dreamy
# Extracted /download/42618-claude-nougaro-le-jazz-et-la-java-2-2
# Extracted /download/50438-jazz-dontget
# Extracted /download/31804-midi-drums-drums-4of6-drums-jazz
# Extracted /download/50426-jazz-deadend
# Extracted /download/29118-jazzblue
# Extracted /download/31408-midi-drums-drums-1of6-drums-jazzbrsh
# Extracted /download/34484-sonar-jazz-167-funky-tom-groove
# Extracted /download/50403-jazz-bigbndballad
# Extracted /download/32619-modjazz
# Extracted /download/34521-song-book-25jazz
# Extracted /download/25920-drumtrax-library-1-trk-type0-jazz-jaz-142
# Extracted /download/20240-018-jazz
# Extracted /download/50611-jazz-unknown-jp070
# Extracted /download/26645-drumtrax-library-2-trk-type1-jazz-jaz-240
# Extracted /download/25915-drumtrax-library-1-trk-type0-jazz-jaz-122
# Extracted /download/15867-game-system-nintendo-super-mario-bros
# Extracted /download/12433-game-system-gameboy-pokemon-trading-card-game-lightning-club-jazz-remix-sequenced-by-dr
# Extracted /download/25917-drumtrax-library-1-trk-type0-jazz-jaz-123
# Extracted /download/19699-game-system-super-nintendo-super-mario-world-donut-plains-jazz-remix-sequenced-by-jkiub--j450n
# Extracted /download/20145-sapphire-gym-leader-battle-jazz-remix
# Extracted /download/50455-jazz-girl-from-ipanema
# Extracted /download/25927-drumtrax-library-1-trk-type0-jazz-jaz-240
# Extracted /download/25918-drumtrax-library-1-trk-type0-jazz-jaz-124
# Extracted /download/50437-jazz-don-lee
# Extracted /download/17474-game-system-super-nintendo-final-fantasy-ii-chocobo-chocobo-jazz-remix-sequenced-by-jimmy-emanuelsson-jimmy-em
# Extracted /download/25733-drumtrax-library-25jazz
# Extracted /download/15186-game-system-nintendo-legend-of-zelda-the-overworld-jazz-remix
# Extracted /download/50456-jazz-girl-talk
# Extracted /download/50460-jazz-happybdy
# Extracted /download/25911-drumtrax-library-1-trk-type0-jazz-jaz-119
# Extracted /download/50475-jazz-la-boite-de-jazz
# Extracted /download/20818-211days-of-wine--roses-midi-jazz-days1
# Extracted /download/25926-drumtrax-library-1-trk-type0-jazz-jaz-167
# Extracted /download/5266-jazzblue2
# Extracted /download/50495-jazz-onestep
# Extracted /download/25923-drumtrax-library-1-trk-type0-jazz-jaz-162
# Extracted /download/25919-drumtrax-library-1-trk-type0-jazz-jaz-137
# Extracted /download/91291-influenciadojazz
# Extracted /download/25908-drumtrax-library-1-trk-type0-jazz-jaz-107
# Extracted /download/14803-game-system-nintendo-final-fantasy-battle-victory-jazz-remix-v2
# Extracted /download/50405-jazz-birlan2
# Extracted /download/50477-jazz-lazybird
# Extracted /download/81465-jazzrock
# Extracted /download/50457-jazz-gmblues1
# Extracted /download/50406-jazz-black-orpheus
# Extracted /download/54727-nougaro-claude-le-jazz-et-la-java-2
# Extracted /download/50534-jazz-unknown-b-flat-blues
# Extracted /download/50431-jazz-dixieland1
# Extracted /download/26274-drumtrax-library-2-trk-type0-jazz-jaz-122
# Extracted /download/50486-jazz-monk
# Extracted /download/50605-jazz-unknown-jp064
# Extracted /download/50465-jazz-israel
# Extracted /download/50388-jazz-ambiant
# Extracted /download/50520-jazz-stolen
# Extracted /download/50389-jazz-anotheru
# Extracted /download/25913-drumtrax-library-1-trk-type0-jazz-jaz-120a
# Extracted /download/26639-drumtrax-library-2-trk-type1-jazz-jaz-144
# Extracted /download/26281-drumtrax-library-2-trk-type0-jazz-jaz-150
# Extracted /download/50418-jazz-cool-jazz
# Extracted /download/26642-drumtrax-library-2-trk-type1-jazz-jaz-162a
# Extracted /download/50450-jazz-gdvib6
# Extracted /download/31409-midi-drums-drums-1of6-drums-jazzsw-a
# Extracted /download/20839-3-jazz-midi-yule-emmanuel-jazz
# Extracted /download/50501-jazz-ppanth
# Extracted /download/50558-jazz-unknown-jp017
# Extracted /download/50540-jazz-unknown-how-insensitive
# Extracted /download/26269-drumtrax-library-2-trk-type0-jazz-jaz-118
# Extracted /download/50394-jazz-be-boppa
# Extracted /download/50458-jazz-gtrblues
# Extracted /download/50521-jazz-stthomas
# Extracted /download/26280-drumtrax-library-2-trk-type0-jazz-jaz-144
# Extracted /download/50461-jazz-improv-1
# Extracted /download/21031-aaa-sound-site-midi-files-the-sound-site-best-of-jazz-volume-2
# Extracted /download/31406-midi-drums-drums-1of6-drums-jazz
# Extracted /download/50436-jazz-dolphnst
# Extracted /download/50464-jazz-ipanema
# Extracted /download/50476-jazz-la-foule
# Extracted /download/29115-jazz-tatrain
# Extracted /download/50472-jazz-jobim
# Extracted /download/50565-jazz-unknown-jp024
# Extracted /download/50587-jazz-unknown-jp046
# Extracted /download/26992-drumtrax-library-sep-trktype1-jazz-jaz-122
# Extracted /download/73375-italian-conte-t1000-sotto-le-stelle-del-jazz-conte
# Extracted /download/26271-drumtrax-library-2-trk-type0-jazz-jaz-120
# Extracted /download/26632-drumtrax-library-2-trk-type1-jazz-jaz-120b
# Extracted /download/50513-jazz-slanted
# Extracted /download/26285-drumtrax-library-2-trk-type0-jazz-jaz-167
# Extracted /download/50539-jazz-unknown-donnalee
# Extracted /download/50399-jazz-bigband-jazz
# Extracted /download/50441-jazz-dreamy2
# Extracted /download/29109-jazz-gipanema
# Extracted /download/4248-jazzy
# Extracted /download/27001-drumtrax-library-sep-trktype1-jazz-jaz-162a
# Extracted /download/27004-drumtrax-library-sep-trktype1-jazz-jaz-240
# Extracted /download/50508-jazz-roadtrav
# Extracted /download/50420-jazz-cool
# Extracted /download/21991-awm-songs-jazzjung
# Extracted /download/50382-jazz-acid-jazz
# Extracted /download/29116-jazz-who-can-i-turn-to-jazz
# Extracted /download/50585-jazz-unknown-jp044
# Extracted /download/50485-jazz-moaning
# Extracted /download/26984-drumtrax-library-sep-trktype1-jazz-jaz-085
# Extracted /download/50439-jazz-dontmean
# Extracted /download/16130-game-system-nintendo-who-framed-roger-rabbit-l
# Extracted /download/31411-midi-drums-drums-1of6-drums-jazzsw-f
# Extracted /download/26634-drumtrax-library-2-trk-type1-jazz-jaz-122a
# Extracted /download/29108-jazz-beginbeg
# Extracted /download/30879-midi-drum-patterns-vol-1-to-vol-4-drums-1of4-drums-swjazz
# Extracted /download/50479-jazz-mechano
# Extracted /download/25921-drumtrax-library-1-trk-type0-jazz-jaz-144
# Extracted /download/50407-jazz-bluesy2
# Extracted /download/29112-jazz-macknife
# Extracted /download/26284-drumtrax-library-2-trk-type0-jazz-jaz-164
# Extracted /download/50503-jazz-prel-kis
# Extracted /download/50598-jazz-unknown-jp057
# Extracted /download/50623-jazz-wivelove
# Downloaded 50556-jazz-unknown-jp015
# Downloaded 26994-drumtrax-library-sep-trktype1-jazz-jaz-123
# Downloaded 26279-drumtrax-library-2-trk-type0-jazz-jaz-142
# Downloaded 50407-jazz-bluesy2
# Downloaded 50604-jazz-unknown-jp063
# Downloaded 26638-drumtrax-library-2-trk-type1-jazz-jaz-142
# Downloaded 50625-jazz-yebisu
# MIDI files downloaded successfully.

# %%
import aiohttp
async def download_hrefs(url):
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as response:
            # Parse the HTML content using BeautifulSoup
            soup = BeautifulSoup(await response.text(), "html.parser")

            # Find all elements with the class "btn btn-primary btn-lg btn-block p-4"
            elements = soup.find_all(class_="btn btn-primary btn-lg btn-block p-4")

            # Extract the hrefs from the elements
            hrefs = [element["href"] for element in elements]

            return hrefs
        
async def download_midi(url, session):
    # Extract the filename from the URL
    filename = url.split("/")[-1]

    # Check if the file already exists in the directory
    if os.path.exists(f"midi_data/{filename}"):
        print(f"Skipping {filename} (already exists)")
        return

    async with session.get(url) as response:
        # Save the MIDI file to the "midi_data" folder
        with open(f"midi_data/{filename}", "wb") as file:
            file.write(await response.read())

        print(f"Downloaded {filename}")

async def main():
    # Create the "midi_data" folder if it doesn't exist
    if not os.path.exists("midi_data"):
        os.makedirs("midi_data")

    download_links = []

    # Iterate over the URLs in all_hrefs
    for url in all_hrefs:
        url = "https://www.midis101.com" + url

        # Send a GET request to the URL
        hrefs = await download_hrefs(url)

        # Add the extracted hrefs to the list
        download_links.extend(hrefs)

    # Print the extracted hrefs
    print(download_links)

    # Download MIDI files from the URLs in download_links
    tasks = []
    async with aiohttp.ClientSession() as session:
        for url in download_links:
            url = "https://www.midis101.com" + url
            tasks.append(asyncio.create_task(download_midi(url, session)))

        await asyncio.gather(*tasks)

    print("MIDI files downloaded successfully.")
    

await main()
# Out:
# []
# MIDI files downloaded successfully.

# %% [markdown]
# ## Synchronous implementation

# %%
# Create the "midi_data" folder if it doesn't exist
if not os.path.exists("midi_data"):
    os.makedirs("midi_data")
    # Create a list to store the extracted hrefs

download_links = []

    # Iterate over the URLs in all_hrefs
for url in all_hrefs:
    url = "https://www.midis101.com" + url
    # Send a GET request to the URL
    response = requests.get(url)

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all elements with the class "btn btn-primary btn-lg btn-block p-4"
    elements = soup.find_all(class_="btn btn-primary btn-lg btn-block p-4")

    # Extract the hrefs from the elements
    hrefs = [element["href"] for element in elements]

    # Add the extracted hrefs to the list
    download_links.extend(hrefs)

# Print the extracted hrefs
print(download_links)

# %%
# Download MIDI files from the URLs in all_hrefs
for url in download_links:
    # Send a GET request to the URL
    response = requests.get(url)

    # Extract the filename from the URL
    filename = url.split("/")[-1]

    # Save the MIDI file to the "data" folder
    with open(f"midi_data/{filename}", "wb") as file:
        file.write(response.content)

print("MIDI files downloaded successfully.")

# %%
import dbt

# %%
with open('../config.yaml', 'r') as config_file:
            config = yaml.safe_load(config_file)
            
sequence_length = config['sequence_length']

# %%
sequence_length
# Out:
# 100
